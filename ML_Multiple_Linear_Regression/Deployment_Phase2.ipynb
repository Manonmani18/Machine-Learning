# %%
import pickle

# %%
# load the saved model

loaded_model = pickle.load(open('finalized_mode_multi_linear.sav','rb'))

# get input from the user

user_RD = float(input('Enter R&D Spend:')) 
user_Admin = float(input('Enter Administration:')) 
user_Mark = float(input('Enter Marketing Spend:')) 
user_flo = int(input('Enter State_Florida 0 or 1:')) 
user_NY = int(input('Enter State_New York 0 or 1:')) 

# predict loaded model

result = loaded_model.predict([[user_RD,user_Admin,user_Mark,user_flo,user_NY]])
result
# Out:
# Enter R&D Spend: 200
# Enter Administration: 2000
# Enter Marketing Spend: 300
# Enter State_Florida 0 or 1: 1
# Enter State_New York 0 or 1: 1
# C:\Users\MANONMANI\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[43399.56557654]])
