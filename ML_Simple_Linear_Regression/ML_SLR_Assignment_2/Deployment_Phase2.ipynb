# %%
# in phase 2 deployment we just import the module and do the load model procedure.
import pickle

# %%
load_model = pickle.load(open('finalized_model_linear.sav','rb'))
u_exp = int(input('Enter the years of experience:'))
result = load_model.predict([[u_exp]])
result
# Out:
# Enter the years of experience: 0
# C:\Users\MANONMANI\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[26777.3913412]])
