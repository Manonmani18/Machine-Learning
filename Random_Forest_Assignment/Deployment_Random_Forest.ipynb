# %%
import pickle

# %%
load_model = pickle.load(open('final_model_random_forest.sav','rb'))
result = load_model.predict([[1234,2345,223,22,0]])
result
# Out:
# C:\Users\MANONMANI\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([51885.0982])
