# %%
import pickle

# %%
load_model = pickle.load(open('final_model_RF.sav','rb'))
age=int(input('Enter the age:'))
bmi=float(input('Enter the bmi:'))
child=int(input('Enter the children:'))
gender=int(input('Enter the gender male(0) or female(1):'))
smoker=int(input('Enter the smoker yes(1) or no(0):'))
result = load_model.predict([[age,bmi,child,gender,smoker]])
result
# Out:
# Enter the age: 25
# Enter the bmi: 19.0
# Enter the children: 2
# Enter the gender male(0) or female(1): 1
# Enter the smoker yes(1) or no(0): 0
# C:\Users\MANONMANI\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([4340.5515628])
